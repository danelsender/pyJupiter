# %%
import os
import matplotlib.pyplot as plt
outputdir = '/home/ipa/ipaszulagyi/users/delsender/adiab_1e-2/adiab_3D_g_1e-2'

import pyJupiter as jup

os.chdir(outputdir)

N = 99

# %%
fig = jup.output(N)

fig.plotvertslice(field='gastemperature',polar=True)

# %%
temp_min, temp_max = jup.get(99).global_minmax(field='gasdensity')

# %%
print(f"minimum dens is: {temp_min}, \n maximum dens is: {temp_max}")
# Out:
# minimum dens is: 8.335419586749406e-08,
#  maximum dens is: 1.3388627163759508

# %%
for i in range(1,100):
    jup.output(i).plotvertslice(field='gastemperature',polar=True,save=True,filename='adiab_vert_1e-2_temp')
